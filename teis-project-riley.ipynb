# %%
import pandas as pd

# %%
scores = pd.read_csv('./data/bdi3.csv')
scores
# Out:
# C:\Users\riley\AppData\Local\Temp\ipykernel_15284\3410521974.py:1: DtypeWarning: Columns (0,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   scores = pd.read_csv('./data/bdi3.csv')
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F     9/27/2022              Southwest
# 1        47795      F    12/23/2020      Greater Nashville
# 2        54340      M     6/22/2021        First Tennessee
# 3        54344      F      3/7/2022    Southeast Tennessee
# 4        54515      M     11/4/2021          Memphis Delta
# ...        ...    ...           ...                    ...
# 23942  SP03287      F     9/25/2023          Memphis Delta
# 23943  SP03288      F     5/18/2021          South Central
# 23944  SP03289      F    10/31/2021          South Central
# 23945  SP03290      M     3/25/2020          Memphis Delta
# 23946  SP03291      M     9/18/2023      Greater Nashville
#
# ...

# %%
scores.Gender.value_counts()
# Out:
# Gender
# M    14732
# F     8801
# U      414
# Name: count, dtype: int64

# %%
scores['Location - Sub Level 1'].value_counts()
# Out:
# Location - Sub Level 1
# Greater Nashville      4262
# East Tennessee         3866
# Memphis Delta          3309
# South Central          3287
# Upper Cumberland       2614
# First Tennessee        2045
# Southeast Tennessee    1873
# Southwest              1352
# Northwest              1207
# Name: count, dtype: int64
