# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. In which domains (and sub-domains) are children performing highest and lowest?

# %% [markdown]
# Adaptive Domain

# %%
adaptive_domain = pd.read_csv('../data/adaptive_domain.csv')
# Out:
# C:\Users\jillz\AppData\Local\Temp\ipykernel_29256\3893438446.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   adaptive_domain = pd.read_csv('../data/adaptive_domain.csv')

# %%
adaptive_domain = adaptive_domain.drop(columns = ['Unnamed: 0'])

# %%
adaptive_domain['Adaptive Sum of Scaled Scores'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
adaptive_domain['Adaptive-Self Care SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
adaptive_domain['Adaptive-Personal Responsibility SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %% [markdown]
# Social Domain

# %%
social_domain = pd.read_csv('../data/social_domain.csv')
# Out:
# C:\Users\jillz\AppData\Local\Temp\ipykernel_29256\643503013.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   social_domain = pd.read_csv('../data/social_domain.csv')

# %%
social_domain = social_domain.drop(columns = ['Unnamed: 0'])

# %%
social_domain['Social-Emotional Sum of Scaled Scores'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
social_domain['Social Emotional-Adult Interaction SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
social_domain['Social Emotional-Peer Interaction SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
social_domain['Social Emotional-Self Concept / Social Role SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %% [markdown]
# Communication Domain

# %%
communication_domain = pd.read_csv('../data/communication_domain.csv')
# Out:
# C:\Users\jillz\AppData\Local\Temp\ipykernel_29256\208292754.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   communication_domain = pd.read_csv('../data/communication_domain.csv')

# %%
communication_domain = communication_domain.drop(columns = ['Unnamed: 0'])

# %%
communication_domain.columns.to_list()
# Out:
# ['Child ID',
#  'Gender',
#  'Date of Birth',
#  'Location - Sub Level 1',
#  'Program Label',
#  'Communication Sum of Scaled Scores',
#  'Communication Developmental Quotient',
#  'Communication Percentile Rank',
#  'Communication 95% Confidence Interval',
#  'Communication RDI',
#  'Communication Z-Score',
#  'Communication T-Score',
#  'Communication NCE',
#  'Communication-Receptive Communication Examiner',
#  'Communication-Receptive Communication Date of Testing',
#  'Communication-Receptive Communication RS',
#  'Communication-Receptive Communication SS',
#  'Communication-Receptive Communication PR',
#  'Communication-Receptive Communication AE',
#  'Communication-Receptive Communication RDI',
#  'Communication-Receptive Communication CSS',
#  'Communication-Receptive Communication CSS 90% ',
#  'Communication-Receptive Communication Z-Score',
#  'Communication-Receptive Communication T-Score',
#  'Communication-Receptive Communication NCE',
# ...

# %%
communication_domain['Communication Sum of Scaled Scores'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
communication_domain['Communication-Receptive Communication SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
communication_domain['Communication-Expressive Communication SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %% [markdown]
# Motor Domain

# %%
motor_domain = pd.read_csv('../data/motor_domain.csv')
# Out:
# C:\Users\jillz\AppData\Local\Temp\ipykernel_29256\3737293166.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   motor_domain = pd.read_csv('../data/motor_domain.csv')

# %%
motor_domain = motor_domain.drop(columns = ['Unnamed: 0'])

# %%
motor_domain.columns.to_list()
# Out:
# ['Child ID',
#  'Gender',
#  'Date of Birth',
#  'Location - Sub Level 1',
#  'Program Label',
#  'Motor Sum of Scaled Scores',
#  'Motor Developmental Quotient',
#  'Motor Percentile Rank',
#  'Motor 95% Confidence Interval',
#  'Motor RDI',
#  'Motor Z-Score',
#  'Motor T-Score',
#  'Motor NCE',
#  'Motor-Gross Motor Examiner',
#  'Motor-Gross Motor Date of Testing',
#  'Motor-Gross Motor RS',
#  'Motor-Gross Motor SS',
#  'Motor-Gross Motor PR',
#  'Motor-Gross Motor AE',
#  'Motor-Gross Motor RDI',
#  'Motor-Gross Motor CSS',
#  'Motor-Gross Motor CSS 90% ',
#  'Motor-Gross Motor Z-Score',
#  'Motor-Gross Motor T-Score',
#  'Motor-Gross Motor NCE',
#  'Motor-Fine Motor Examiner',
#  'Motor-Fine Motor Date of Testing',
#  'Motor-Fine Motor RS',
#  'Motor-Fine Motor SS',
#  'Motor-Fine Motor PR',
#  'Motor-Fine Motor AE',
#  'Motor-Fine Motor RDI',
#  'Motor-Fine Motor CSS',
#  'Motor-Fine Motor CSS 90%',
#  'Motor-Fine Motor Z-Score',
#  'Motor-Fine Motor T-Score',
# ...

# %%
motor_domain['Motor Sum of Scaled Scores'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
motor_domain['Motor-Gross Motor SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
motor_domain['Motor-Fine Motor SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
motor_domain['Motor-Perceptual Motor SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %% [markdown]
# Cognitive Domain

# %%
cognitive_domain = pd.read_csv('../data/cognitive_domain.csv')
# Out:
# C:\Users\jillz\AppData\Local\Temp\ipykernel_29256\3191090248.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   cognitive_domain = pd.read_csv('../data/cognitive_domain.csv')

# %%
cognitive_domain = cognitive_domain.drop(columns = ['Unnamed: 0'])

# %%
cognitive_domain.columns.to_list()
# Out:
# ['Child ID',
#  'Gender',
#  'Date of Birth',
#  'Location - Sub Level 1',
#  'Program Label',
#  'Cognitive Sum of Scaled Scores',
#  'Cognitive Developmental Quotient',
#  'Cognitive Percentile Rank',
#  'Cognitive 95% Confidence Interval',
#  'Cognitive RDI',
#  'Cognitive Z-Score',
#  'Cognitive T-Score',
#  'Cognitive NCE',
#  'Cognitive-Attention and Memory Examiner',
#  'Cognitive-Attention and Memory Date of Testing',
#  'Cognitive-Attention and Memory RS',
#  'Cognitive-Attention and Memory SS',
#  'Cognitive-Attention and Memory PR',
#  'Cognitive-Attention and Memory AE',
#  'Cognitive-Attention and Memory RDI',
#  'Cognitive-Attention and Memory CSS',
#  'Cognitive-Attention and Memory CSS 90%',
#  'Cognitive-Attention and Memory Z-Score',
#  'Cognitive-Attention and Memory T-Score',
#  'Cognitive-Attention and Memory NCE',
#  'Cognitive-Reasoning / Academic Skills Examiner',
#  'Cognitive-Reasoning / Academic Skills Date of Testing',
# ...

# %%
cognitive_domain['Cognitive Sum of Scaled Scores'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
cognitive_domain['Cognitive-Attention and Memory SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
cognitive_domain['Cognitive-Reasoning / Academic Skills SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %%
cognitive_domain['Cognitive-Perception and Concepts SS'].value_counts(dropna = True).sort_index().plot(kind = 'bar');

# %% [markdown]
# 2. What is the pattern of children's scores? Do individual children tend to perform similarly across all domains or are there differences from domain to domain? Are these patterns similar for all children?
